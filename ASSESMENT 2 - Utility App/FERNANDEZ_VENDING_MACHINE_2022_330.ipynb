# %%
#Store the items as dictionary.
items = [
    {
        'code': 0,
        'name': 'Water',
        'price': 2
    },
    {
        'code': 1,
        'name': 'Chocolates',
        'price': 7
    },
    {
        'code': 2,
        'name': 'chips',
        'price': 6
    },
    {
        'code': 3,
        'name': 'Cold Coffee',
        'price': 8
    },
    {
        'code': 4,
        'name': 'Fresh Milk',
        'price': 10
    },
    {
        'code': 5,
        'name': 'Soda',
        'price': 8
    },
    {
        'code': 6,
        'name': 'Ice Cream',
        'price': 12
    },
]

quit_vm = False
item = ''

#Print the items that are available these are the items that are metioned from above.
while quit_vm == False:
    print("Welcome to the vending machine")
    for i in items:
        print(f"Item Name: {i['name']} - Price: {i['price']} - code: {i['code']}")

#Letting the user choose item they want to buy.
    query = int(input("Enter the code number of the item you want to buy: "))
    for i in items:
        if query == i['code']:
            item = i
#Using the if-else function to make the program funtion.
    if item == '': 
        print('INVALID CODE')
    else:
        print(f"Nice Choice, {item['name']} will cost you {item['price']} dollars")

        bill = int(input(f"Enter {item['price']} dollars to purchase: "))
        if bill == item['price']:
            print(f"Thank you for buying in our vending machine here is your {item['name']}")
        else:
            print(f"Please enter only {item['price']} dollars")

#Ask the user if they're going to continue buying or quit after buying only one item they can either choose "c" or "q".
    query = input("To quit the machine kindly enter q and to continue buying enter c: ")
    if query == 'c':
        quit_vm = False
        query = int(input("What would you like to add? please enter the code you want to add: "))
    for i in items:
       if query == i['code']:
            item = i
    if item == '':
        print('INVALID CODE')
    else:
        quit_vm = True
        print(f"This will cost you {item['price']} dolars")

#Asking the user to add the bill to make a purchase.
while query:
  print(f"{item['name']} has been added")
  bill = int(input(f"Enter {item['price']} dollars to purchase: "))
  if bill == item['price']:
            print(f"Thank you for buying in our vending machine here is your {item['name']}")
  else:
            print(f"Please enter only {item['price']} dollars")

#Asking user again if there is anything else they want to add on their purchase.
  end_query = (input("Is there anything else? please enter c to continue any q to quit: "))
  if end_query == 'c':
     quit_vm = False
  else:
    quit_vm = True
    print('')
#End.
    print('Thank You, have a nice day! Please come again...\n')
    break
# Out:
# Welcome to the vending machine
# Item Name: Water - Price: 2 - code: 0
# Item Name: Chocolates - Price: 7 - code: 1
# Item Name: chips - Price: 6 - code: 2
# Item Name: Cold Coffee - Price: 8 - code: 3
# Item Name: Fresh Milk - Price: 10 - code: 4
# Item Name: Soda - Price: 8 - code: 5
# Item Name: Ice Cream - Price: 12 - code: 6
# Enter the code number of the item you want to buy: 3
# Nice Choice, Cold Coffee will cost you 8 dollars
# Enter 8 dollars to purchase: 8
# Thank you for buying in our vending machine here is your Cold Coffee
# To quit the machine kindly enter q and to continue buying enter c: c
# What would you like to add? please enter the code you want to add: 6
# This will cost you 12 dolars
# Ice Cream has been added
# Enter 12 dollars to purchase: 12
# Thank you for buying in our vending machine here is your Ice Cream
# Is there anything else? please enter c to continue any q to quit: q
#
# Thank You, have a nice day! Please come again...
